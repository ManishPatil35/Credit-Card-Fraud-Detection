# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/creditcard.csv')
# Out:
# <ipython-input-7-a64c6380bf75>:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/creditcard.csv')

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33760 entries, 0 to 33759
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    33760 non-null  int64
#  1   V1      33760 non-null  float64
#  2   V2      33760 non-null  float64
#  3   V3      33760 non-null  float64
#  4   V4      33760 non-null  float64
#  5   V5      33760 non-null  float64
#  6   V6      33760 non-null  float64
#  7   V7      33760 non-null  float64
#  8   V8      33760 non-null  float64
#  9   V9      33760 non-null  float64
#  10  V10     33760 non-null  float64
#  11  V11     33760 non-null  float64
#  12  V12     33760 non-null  float64
#  13  V13     33760 non-null  float64
#  14  V14     33760 non-null  float64
#  15  V15     33760 non-null  float64
#  16  V16     33760 non-null  float64
#  17  V17     33760 non-null  float64
#  18  V18     33760 non-null  float64
#  19  V19     33760 non-null  float64
#  20  V20     33760 non-null  float64
#  21  V21     33760 non-null  float64
#  22  V22     33760 non-null  object
#  23  V23     33759 non-null  float64
#  24  V24     33759 non-null  float64
#  25  V25     33759 non-null  float64
#  26  V26     33759 non-null  float64
#  27  V27     33759 non-null  float64
#  28  V28     33759 non-null  float64
#  29  Amount  33759 non-null  float64
#  30  Class   33759 non-null  float64
# dtypes: float64(29), int64(1), object(1)
# memory usage: 8.0+ MB

# %%
#Checking missing values in each column

df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# Impute missing values with the mean of the column
df['V23'].fillna(df['V23'].mean(), inplace=True)
df['V24'].fillna(df['V24'].mean(), inplace=True)
df['V25'].fillna(df['V25'].mean(), inplace=True)
df['V26'].fillna(df['V26'].mean(), inplace=True)
df['V27'].fillna(df['V27'].mean(), inplace=True)
df['V28'].fillna(df['V28'].mean(), inplace=True)
df['Amount'].fillna(df['Amount'].mean(), inplace=True)
df['Class'].fillna(df['Class'].mean(), inplace=True)

# %%
df['Class'] = df['Class'].astype(int)

# %%
df['Class'].value_counts()
# Out:
# 0    33657
# 1      103
# Name: Class, dtype: int64

# %%
#Data is imbalanced as 0---> Normal data is Huge and 1--->Fraud Data is Low
#So it will predict every transaction as normal one .

# Hence , Splitting data into 0 and 1 for analysis

LegitData = df[df.Class==0]
FraudData = df[df.Class==1]

# %%
print(LegitData.shape)
print(FraudData.shape)
# Out:
# (33657, 31)
# (103, 31)

# %%
#Statistical Measure of Data

#Legit Amount data Analysis

LegitData.Amount.describe()
# Out:
# count    33657.000000
# mean        83.011607
# std        227.807619
# min          0.000000
# 25%          6.990000
# 50%         21.050000
# 75%         75.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
#Fraud Amount data analysis

FraudData.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#Compare Values for both Transaction

df.groupby('Class').mean()
# Out:
# <ipython-input-26-0798a0a2b836>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Class').mean()
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0      23194.728734 -0.187658  0.072620   0.753816  0.187720 -0.199312
# 1      20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V19       V20  \
# Class                                          ...
# 0      0.100303 -0.094706  0.020034  0.295422  ... -0.038618  0.043098
# 1     -2.306085 -7.743100  3.867920 -2.961800  ...  0.477900  0.652319
#
#             V21       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.033938 -0.041512  0.009386  0.134676  0.021468  0.009748  0.003296
# 1      0.628539 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0      83.011607
# 1      90.471165
#
# [2 rows x 29 columns]

# %%
#Build a samle dataset of Legit Transaction and Fraud Transaction
#Fraud Transaction are 103
#We will choose 103 random Transaction from legit transaction and join in legit data
#This makes a uniformly distributed dataset which is good for modelling

Legit_sample = LegitData.sample(n=103)

# %%
#Concantetanate 2 DataFrame

newdf = pd.concat([Legit_sample,FraudData],axis=0)

# %%
newdf.tail(5)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21                V22  \
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042           0.920021
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473           0.614573
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888          -0.845753
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641           -0.96296
# 33276 -5.283435  0.131619  0.658176  ... -0.734308  -0.59992625988411
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# 30442 -0.151104  0.011007  0.080303  0.412191  0.635789  0.501050    4.56
# 30473  0.028521  0.013704 -0.149512 -0.131687  0.473934  0.473757   14.46
# 30496  0.190674 -0.216443 -0.325033 -0.270328  0.210214  0.391855  111.70
# 31002 -0.110045 -0.177733 -0.089175 -0.049447  0.303445  0.219380  111.70
# 33276 -4.908301  0.410170 -1.167660  0.520508  1.937421 -1.552593   12.31
#
#        Class
# 30442      1
# 30473      1
# 30496      1
# 31002      1
# 33276      1
#
# [5 rows x 31 columns]

# %%
newdf['Class'].value_counts()
# Out:
# 0    103
# 1    103
# Name: Class, dtype: int64

# %%
#Compare Values for both Transaction
#If values are highly different then it is a bad sample
#If values are almost same then it is a good sample
#Below we are getting almost similiar data as of the old imbalanced dataset and newly created dataset

newdf.groupby('Class').mean()
# Out:
# <ipython-input-32-b036dbd070ed>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   newdf.groupby('Class').mean()
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0      21201.815534  0.045279  0.114603   0.873668  0.374484 -0.245820
# 1      20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V19       V20  \
# Class                                          ...
# 0      0.074486  0.062834  0.043451  0.187685  ... -0.038052  0.071460
# 1     -2.306085 -7.743100  3.867920 -2.961800  ...  0.477900  0.652319
#
#             V21       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.080565 -0.019036 -0.065101  0.115885  0.074425  0.025568  0.019450
# 1      0.628539 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0      87.594466
# 1      90.471165
#
# [2 rows x 29 columns]

# %%
#Split Data into Features and Target
# Axis=0 represent ROW and Axis=1 represent COLUMN

X = newdf.drop(columns='Class' , axis=1)
y = newdf['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 6526    7864  0.475494  2.102621 -2.001822  1.919916  0.771322 -1.871277
# 2267    1812 -1.243354 -1.085595  1.049266 -0.838813 -6.048410  2.697311
# 26153  33934  1.082372  0.104223  0.352009  1.045444  0.005641  0.372987
# 10779  18344 -0.480232  1.133591  1.392438  0.772522  0.512337 -0.459334
# 16104  27521 -0.599420  1.013075  2.407219  2.653114  0.107038  0.561448
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V20       V21  \
# 6526   0.544273  0.029546  0.680662  ... -0.022782 -0.249712
# 2267   3.366720 -0.593869  0.559513  ... -0.923957 -0.151061
# 26153 -0.177630  0.276607 -0.141425  ... -0.232446  0.173802
# 10779  1.744949 -0.782441  0.804726  ... -0.144824 -0.117844
# 16104  0.083852  0.274427 -1.610516  ...  0.261405  0.227769
# ...         ...       ...       ...  ...       ...       ...
# 30442 -6.805053  2.928356 -4.917130  ...  0.757287  1.691042
# 30473 -7.281328  3.332250 -3.679659  ...  0.579098  1.550473
# 30496 -6.311699  3.449167 -5.416284  ...  0.284555  1.194888
# 31002 -6.958679  3.877795 -5.541529  ...  0.299489  1.128641
# 33276 -5.283435  0.131619  0.658176  ... -2.169811 -0.734308
#
#                      V22       V23       V24       V25       V26       V27  \
# 6526           -0.314876  0.139189 -0.006848 -0.440295 -0.439186  0.109554
# 2267            0.867403 -0.158219  0.849282  0.013025 -0.240977  0.361155
# 26153           0.515009 -0.059300 -0.295442  0.460748 -0.237215  0.039478
# 10779           0.257781 -0.228626  0.331822  0.163459 -0.427539 -0.514905
# 16104           0.547653 -0.289655  0.006145  0.134873  0.356172  0.084442
# ...                  ...       ...       ...       ...       ...       ...
# 30442           0.920021 -0.151104  0.011007  0.080303  0.412191  0.635789
# 30473           0.614573  0.028521  0.013704 -0.149512 -0.131687  0.473934
# 30496          -0.845753  0.190674 -0.216443 -0.325033 -0.270328  0.210214
# 31002           -0.96296 -0.110045 -0.177733 -0.089175 -0.049447  0.303445
# 33276  -0.59992625988411 -4.908301  0.410170 -1.167660  0.520508  1.937421
#
#             V28  Amount
# 6526  -0.052415    0.93
# 2267  -0.187707  980.00
# 26153  0.005015   14.98
# 10779 -0.431945   79.80
# 16104  0.084362   18.61
# ...         ...     ...
# 30442  0.501050    4.56
# 30473  0.473757   14.46
# 30496  0.391855  111.70
# 31002  0.219380  111.70
# 33276 -1.552593   12.31
#
# [206 rows x 30 columns]

# %%
print(y)
# Out:
# 6526     0
# 2267     0
# 26153    0
# 10779    0
# 16104    0
#         ..
# 30442    1
# 30473    1
# 30496    1
# 31002    1
# 33276    1
# Name: Class, Length: 206, dtype: int64

# %%
#Split Data into Training Data and Testing Data

X_train , X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(X.shape , X_train.shape , X_test.shape)
# Out:
# (206, 30) (164, 30) (42, 30)

# %%
#Model Training

model = LogisticRegression(max_iter=1000)

#Training the model with training data

model.fit(X_train , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Model Evaluation for Training Data

#Accuracy Score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction , y_train)

# %%
print("Accuracy on Training Data : " , training_data_accuracy )
# Out:
# Accuracy on Training Data :  0.9939024390243902

# %%
#Model Evaluation for Testing Data

#Accuracy Score
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction , y_test)

# %%
print("Accuracy on Training Data : " , testing_data_accuracy )
# Out:
# Accuracy on Training Data :  0.9523809523809523
